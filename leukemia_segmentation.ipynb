# %%
# !nvidia-smi
# Out:
# Fri Apr 12 10:47:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import zipfile

# Specify the path to your zip file
zip_path = "/content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset.zip"

# Specify the directory where you want to extract the contents of the zip file
extract_path = "/content/drive/MyDrive/alliance_university_2/leukemia/"

# Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Zip file extracted successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a24cf60c534a> in <cell line: 10>()
#       8
#       9 # Extract the zip file
# ---> 10 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#      11     zip_ref.extractall(extract_path)
#      12
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset.zip'

# %%
import os
os.chdir("/content/drive/MyDrive/alliance_university_2/leukemia/")

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/alliance_university_2/leukemia

# %%
# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.1/201.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=/content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/data.yaml epochs=10 imgsz=640 save=true
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s-seg.pt to yolov8s-seg.pt...
# 100% 22.8M/22.8M [00:00<00:00, 156MB/s]
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# yolo/engine/trainer: task=segment, mode=train, model=yolov8s-seg.pt, data=/content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/data.yaml, epochs=10, patience=50, batch=16, imgsz=640, save=True, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/segment/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 43.5MB/s]
# 2024-04-11 13:33:49.491051: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 13:33:49.491110: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 13:33:49.492649: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-11 13:33:50.622358: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2770931  ultralytics.nn.modules.Segment               [1, 32, 128, [128, 256, 512]]
# YOLOv8s-seg summary: 261 layers, 11790483 parameters, 11790467 gradients, 42.7 GFLOPs
#
# Transferred 411/417 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias
# train: Scanning /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/train/labels... 466 images, 0 backgrounds, 0 corrupt: 100% 466/466 [00:06<00:00, 75.19it/s]
# train: New cache created: /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/valid/labels... 29 images, 0 backgrounds, 0 corrupt: 100% 29/29 [00:00<00:00, 84.28it/s]
# val: New cache created: /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/valid/labels.cache
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/segment/train
# Starting training for 10 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      4.86G      1.262      1.592      3.992      0.954          3        640: 100% 30/30 [00:25<00:00,  1.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:02<00:00,  2.28s/it]
#                    all         29        142      0.935      0.508      0.825      0.654      0.935      0.508      0.825      0.478
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      5.45G     0.9624      1.146      1.103     0.8537          3        640: 100% 30/30 [00:17<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.15s/it]
#                    all         29        142       0.89      0.986      0.942      0.719       0.89      0.986      0.942      0.557
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      5.45G      1.044      1.042     0.9428     0.8634          3        640: 100% 30/30 [00:20<00:00,  1.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:02<00:00,  2.23s/it]
#                    all         29        142      0.938      0.979      0.971      0.786      0.938      0.979      0.971      0.654
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      5.45G      1.022      1.056     0.9725     0.8769          3        640: 100% 30/30 [00:16<00:00,  1.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.15s/it]
#                    all         29        142      0.885      0.979       0.97       0.67      0.885      0.979       0.97       0.62
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      5.45G     0.9539      1.042     0.8127     0.8658          7        640: 100% 30/30 [00:17<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.53s/it]
#                    all         29        142      0.927      0.977      0.963      0.726      0.929      0.972      0.963      0.635
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      5.45G     0.9477     0.9107     0.7622     0.8599          3        640: 100% 30/30 [00:17<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.09s/it]
#                    all         29        142      0.931      0.979      0.967      0.736      0.931      0.979      0.967      0.637
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      5.45G     0.8689     0.8871     0.6325     0.8505         11        640: 100% 30/30 [00:16<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.18s/it]
#                    all         29        142       0.92      0.977      0.958      0.773       0.92      0.977      0.958      0.605
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      5.45G     0.7982     0.8764     0.5656     0.8408          5        640: 100% 30/30 [00:16<00:00,  1.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.53s/it]
#                    all         29        142      0.937      0.979      0.947      0.768      0.937      0.979      0.947      0.623
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      5.45G     0.7512     0.8456     0.5645     0.8181         11        640: 100% 30/30 [00:16<00:00,  1.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.16s/it]
#                    all         29        142      0.917      0.972      0.956      0.814      0.917      0.972      0.956      0.646
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      5.45G     0.7158     0.8263     0.5155     0.8186         12        640: 100% 30/30 [00:16<00:00,  1.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all         29        142      0.919      0.965      0.945      0.814      0.919      0.965      0.945       0.66
#
# 10 epochs completed in 0.060 hours.
# Optimizer stripped from runs/segment/train/weights/last.pt, 23.8MB
# Optimizer stripped from runs/segment/train/weights/best.pt, 23.8MB
#
# Validating runs/segment/train/weights/best.pt...
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0% 0/1 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.30s/it]
#                    all         29        142       0.92      0.965      0.946      0.812       0.92      0.965      0.946      0.657
# Speed: 0.2ms pre-process, 1.7ms inference, 0.0ms loss, 1.1ms post-process per image
# Results saved to runs/segment/train

# %%
Image(filename=f'/content/drive/MyDrive/alliance_university_2/leukemia/runs/segment/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/drive/MyDrive/alliance_university_2/leukemia/runs/segment/train/results.png', width=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4404745d97ed> in <cell line: 1>()
# ----> 1 Image(filename=f'/content/drive/MyDrive/alliance_university_2/leukemia/runs/segment/train/results.png', width=600)
#
# NameError: name 'Image' is not defined

# %%
Image(filename=f'/content/drive/MyDrive/alliance_university_2/leukemia/runs/segment/train/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=segment mode=val model=runs/segment/train/weights/best.pt data=leukemia_dataset/data.yaml
# Out:
# 2024-04-11 13:44:14.641895: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 13:44:14.641944: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 13:44:14.643395: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-11 13:44:16.538440: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
# val: Scanning /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/valid/labels.cache... 29 images, 0 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0% 0/2 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:04<00:00,  2.26s/it]
#                    all         29        142       0.92      0.966      0.946      0.824       0.92      0.966      0.946      0.624
# Speed: 0.2ms pre-process, 36.0ms inference, 0.2ms loss, 26.4ms post-process per image

# %%
# !yolo task=segment mode=predict model=runs/segment/train/weights/best.pt conf=0.25 source=leukemia_dataset/test/images save=true
# Out:
# 2024-04-11 13:44:51.477760: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 13:44:51.477816: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 13:44:51.479109: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-11 13:44:52.618557: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/L7170127_JPG_jpg.rf.7591a7fc480ffe1702ce5cac7eb4307a.jpg: 640x640 4 cells, 14.3ms
# image 2/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/n17_jpg.rf.a8a371a091303312e6f9e3df983283ce.jpg: 640x640 6 cells, 14.1ms
# image 3/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/zHA130019_JPG_jpg.rf.18d63e766d86914d6eee5f75d2a986c2.jpg: 640x640 7 cells, 11.8ms
# image 4/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/zHA130020_JPG_jpg.rf.1a80445524ef6dce76bdb8ab41fb027b.jpg: 640x640 7 cells, 11.2ms
# image 5/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/zHA130025_JPG_jpg.rf.bc02380dc63c973bc64bf6eb377c5feb.jpg: 640x640 10 cells, 10.7ms
# image 6/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/zHA200018_JPG_jpg.rf.c9d532707e46d804657ce2a6959da532.jpg: 640x640 2 cells, 11.7ms
# image 7/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/zHA200024_JPG_jpg.rf.e6906eecc534fabb09ea353541c5a989.jpg: 640x640 5 cells, 11.1ms
# image 8/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/zHA200025_JPG_jpg.rf.55545f2117abb07bc0addc836f49068c.jpg: 640x640 3 cells, 12.0ms
# image 9/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/zHA200029_JPG_jpg.rf.22cd08362955e2fe987af806cb05ad35.jpg: 640x640 3 cells, 10.4ms
# image 10/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/zHA200030_JPG_jpg.rf.2bd769609135eff15ce726482bb5819e.jpg: 640x640 4 cells, 10.1ms
# image 11/11 /content/drive/MyDrive/alliance_university_2/leukemia/leukemia_dataset/test/images/zHA200033_JPG_jpg.rf.6bface47b7e9d8937b8e4d90a983acd1.jpg: 640x640 4 cells, 10.1ms
# Speed: 1.0ms pre-process, 11.6ms inference, 53.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'runs/segment/predict/*.jpg'):
      display(Image(filename=image_path, height=600))
      print("\n")

# %% [markdown]
# # CERVICAL LESION

# %%
import zipfile

# Specify the path to your zip file
zip_path = "/content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion.zip"

# Specify the directory where you want to extract the contents of the zip file
extract_path = "/content/drive/MyDrive/alliance_university_2/cervical_lesion/"

# Extract the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Zip file extracted successfully.")
# Out:
# Zip file extracted successfully.

# %%
import os
os.chdir("/content/drive/MyDrive/alliance_university_2/cervical_lesion/")

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/alliance_university_2/cervical_lesion

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=cervical_lesion/data.yaml epochs=10 imgsz=640 save=true
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s-seg.pt to yolov8s-seg.pt...
# 100% 22.8M/22.8M [00:00<00:00, 147MB/s]
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# yolo/engine/trainer: task=segment, mode=train, model=yolov8s-seg.pt, data=cervical_lesion/data.yaml, epochs=10, patience=50, batch=16, imgsz=640, save=True, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/segment/train
# 2024-04-11 15:00:52.852259: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 15:00:52.852331: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 15:00:52.853770: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-11 15:00:53.933850: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2770931  ultralytics.nn.modules.Segment               [1, 32, 128, [128, 256, 512]]
# YOLOv8s-seg summary: 261 layers, 11790483 parameters, 11790467 gradients, 42.7 GFLOPs
#
# Transferred 411/417 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias
# train: Scanning /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/train/labels... 223 images, 0 backgrounds, 0 corrupt: 100% 223/223 [00:02<00:00, 79.43it/s]
# train: New cache created: /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/valid/labels... 37 images, 0 backgrounds, 0 corrupt: 100% 37/37 [00:00<00:00, 112.24it/s]
# val: New cache created: /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/valid/labels.cache
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/segment/train
# Starting training for 10 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      4.53G       2.87      7.681      11.28      3.475         16        640: 100% 14/14 [00:15<00:00,  1.13s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.06it/s]
#                    all         37         37      0.282       0.34      0.214     0.0521      0.196      0.238     0.0853       0.02
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      5.31G      1.981      4.556      2.884      2.694         15        640: 100% 14/14 [00:09<00:00,  1.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.47it/s]
#                    all         37         37      0.372      0.514      0.412       0.16      0.329      0.432      0.334     0.0927
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      5.31G      1.591      3.236      1.556      2.269         15        640: 100% 14/14 [00:09<00:00,  1.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.32it/s]
#                    all         37         37      0.705      0.581      0.682       0.32      0.673      0.556      0.662       0.27
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      5.31G      1.522      2.842      1.349      2.127         16        640: 100% 14/14 [00:09<00:00,  1.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.27it/s]
#                    all         37         37      0.672       0.73      0.729      0.341      0.763      0.784      0.776      0.333
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      5.31G      1.402      2.715      1.082      1.981         15        640: 100% 14/14 [00:09<00:00,  1.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.21s/it]
#                    all         37         37      0.742      0.811      0.812      0.389      0.692      0.757      0.737      0.305
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      5.31G      1.291      2.526      1.001      1.901         15        640: 100% 14/14 [00:08<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.25it/s]
#                    all         37         37      0.816      0.842      0.879      0.426      0.812      0.811      0.808      0.355
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      5.31G      1.259      2.454     0.8991      1.776         15        640: 100% 14/14 [00:07<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.36it/s]
#                    all         37         37      0.832      0.757      0.817      0.353      0.792       0.73      0.752      0.304
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      5.31G      1.143      2.319     0.7037       1.78         15        640: 100% 14/14 [00:09<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.55it/s]
#                    all         37         37      0.832      0.865      0.788      0.437      0.806      0.838      0.769      0.373
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      5.31G      1.079      2.241      0.647      1.691         15        640: 100% 14/14 [00:09<00:00,  1.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.60it/s]
#                    all         37         37      0.765      0.704       0.79      0.423      0.765      0.704      0.772      0.379
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      5.31G       1.06      2.201     0.6541      1.615         16        640: 100% 14/14 [00:10<00:00,  1.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.27s/it]
#                    all         37         37      0.817      0.757      0.764      0.393      0.846      0.784      0.797       0.35
#
# 10 epochs completed in 0.038 hours.
# Optimizer stripped from runs/segment/train/weights/last.pt, 23.8MB
# Optimizer stripped from runs/segment/train/weights/best.pt, 23.8MB
#
# Validating runs/segment/train/weights/best.pt...
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0% 0/2 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.05it/s]
#                    all         37         37      0.833      0.865      0.788      0.437      0.833      0.865      0.835      0.381
# Speed: 0.2ms pre-process, 3.2ms inference, 0.0ms loss, 2.0ms post-process per image
# Results saved to runs/segment/train

# %%
Image(filename=f'runs/segment/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'runs/segment/train/results.png', width=600)

# %%
Image(filename=f'runs/segment/train/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=segment mode=val model=runs/segment/train/weights/best.pt data=cervical_lesion/data.yaml
# Out:
# 2024-04-11 15:07:32.486195: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 15:07:32.486245: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 15:07:32.487678: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-11 15:07:34.120896: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
# val: Scanning /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/valid/labels.cache... 37 images, 0 backgrounds, 0 corrupt: 100% 37/37 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0% 0/3 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 3/3 [00:04<00:00,  1.35s/it]
#                    all         37         37      0.833      0.865      0.788      0.437      0.806      0.838      0.769      0.371
# Speed: 2.7ms pre-process, 37.9ms inference, 0.0ms loss, 17.2ms post-process per image

# %%
# !yolo task=segment mode=predict model=runs/segment/train/weights/best.pt conf=0.25 source=cervical_lesion/test/images save=true
# Out:
# 2024-04-11 15:07:54.564124: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 15:07:54.564177: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 15:07:54.565684: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-11 15:07:55.682640: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AAD1_jpg.rf.1d048fc8e6196483c8ab93b7c89f6098.jpg: 640x640 1 cervical_lesion, 7.7ms
# image 2/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AAT1_jpg.rf.34b43f68faf793b62982c5e9659e7e13.jpg: 640x640 1 cervical_lesion, 7.8ms
# image 3/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AAY1_jpg.rf.ae2e26460bea85eafa326f723611b8ac.jpg: 640x640 1 cervical_lesion, 7.9ms
# image 4/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/ACC1_jpg.rf.6e464ab4208635976c5bd2e6e62ad1ff.jpg: 640x640 1 cervical_lesion, 7.6ms
# image 5/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/ACD1_jpg.rf.4635f3b26ba014e188a489ec64f16b4b.jpg: 640x640 1 cervical_lesion, 7.7ms
# image 6/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/ACI1_jpg.rf.91f8a5f294641ef496dbe7f6699d1e21.jpg: 640x640 1 cervical_lesion, 8.0ms
# image 7/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/ADJ1_jpg.rf.253e1e30e769fa95f8aca3c7606a62fb.jpg: 640x640 1 cervical_lesion, 8.0ms
# image 8/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/ADS1_jpg.rf.241b946b42931973d1e90571a5f503c5.jpg: 640x640 1 cervical_lesion, 8.9ms
# image 9/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AEO1_jpg.rf.07116d2d76b7daf462d54d7f47181d51.jpg: 640x640 1 cervical_lesion, 8.0ms
# image 10/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AEU1_jpg.rf.c3925820d850705bdbb0e58d27c7dc50.jpg: 640x640 1 cervical_lesion, 8.6ms
# image 11/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AFB1_jpg.rf.618f34784d5194f5f465a34c7046dc26.jpg: 640x640 1 cervical_lesion, 8.4ms
# image 12/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AFC1_jpg.rf.a74c587ba458c14cf14a080b5a3cd42b.jpg: 640x640 1 cervical_lesion, 8.0ms
# image 13/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AGA1_jpg.rf.a06aa20d91559f57a5f5668a32a68cd5.jpg: 640x640 1 cervical_lesion, 7.6ms
# image 14/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AHS1_jpg.rf.0ab6c9cac080e31edf0bd6c4b14129ea.jpg: 640x640 1 cervical_lesion, 7.5ms
# image 15/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/AMF1_jpg.rf.736ae9e6e13feccc928c547d5f4b5da6.jpg: 640x640 1 cervical_lesion, 7.7ms
# image 16/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/ANC1_jpg.rf.f1e8b2d71c269ce7066f5e7352e73c17.jpg: 640x640 1 cervical_lesion, 8.5ms
# image 17/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/APF1_jpg.rf.7e6ee55542a1de082a204c35df6c56c0.jpg: 640x640 1 cervical_lesion, 8.4ms
# image 18/18 /content/drive/MyDrive/alliance_university_2/cervical_lesion/cervical_lesion/test/images/APT1_jpg.rf.5f546f5e0590fd47bd0a29b3057c3ae3.jpg: 640x640 1 cervical_lesion, 8.1ms
# Speed: 0.7ms pre-process, 8.0ms inference, 28.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'runs/segment/predict/*.jpg'):
      display(Image(filename=image_path, height=600))
      print("\n")
